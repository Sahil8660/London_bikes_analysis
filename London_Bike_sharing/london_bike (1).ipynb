# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
bikes = pd.read_csv('london_merged.csv')

# %%
bikes
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# ...

# %%
bikes.shape
# Out:
# (17414, 10)

# %%
bikes.weather_code.value_counts()
# Out:
# weather_code
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: count, dtype: int64

# %%
bikes.season.value_counts()
# Out:
# season
# 0.0    4394
# 1.0    4387
# 3.0    4330
# 2.0    4303
# Name: count, dtype: int64

# %%
new_col_dict = {'timestamp':'time',
                'cnt':'count',
                't1':'temp_real_C',
                't2':'temp_feels_like_C',
                'hum':'humidity_per',
                'wind_speed':'wind_speed_percent',
                'weather_code':'weather',
                'is_holiday':'is_holiday',
                'is_weekend':'is_weekend',
                'season':'season'
                }
bikes.rename(new_col_dict,axis=1,inplace=True)

# %%
bikes.head()
# Out:
#                   time  count  temp_real_C  temp_feels_like_C  humidity_per  \
# 0  2015-01-04 00:00:00    182          3.0                2.0          93.0
# 1  2015-01-04 01:00:00    138          3.0                2.5          93.0
# 2  2015-01-04 02:00:00    134          2.5                2.5          96.5
# 3  2015-01-04 03:00:00     72          2.0                2.0         100.0
# 4  2015-01-04 04:00:00     47          2.0                0.0          93.0
#
#    wind_speed_percent  weather  is_holiday  is_weekend  season
# 0                 6.0      3.0         0.0         1.0     3.0
# 1                 5.0      1.0         0.0         1.0     3.0
# 2                 0.0      1.0         0.0         1.0     3.0
# 3                 0.0      1.0         0.0         1.0     3.0
# 4                 6.5      1.0         0.0         1.0     3.0

# %%
bikes.humidity_per = bikes.humidity_per/100

# %%
bikes.head()
# Out:
#                   time  count  temp_real_C  temp_feels_like_C  humidity_per  \
# 0  2015-01-04 00:00:00    182          3.0                2.0         0.930
# 1  2015-01-04 01:00:00    138          3.0                2.5         0.930
# 2  2015-01-04 02:00:00    134          2.5                2.5         0.965
# 3  2015-01-04 03:00:00     72          2.0                2.0         1.000
# 4  2015-01-04 04:00:00     47          2.0                0.0         0.930
#
#    wind_speed_percent  weather  is_holiday  is_weekend  season
# 0                 6.0      3.0         0.0         1.0     3.0
# 1                 5.0      1.0         0.0         1.0     3.0
# 2                 0.0      1.0         0.0         1.0     3.0
# 3                 0.0      1.0         0.0         1.0     3.0
# 4                 6.5      1.0         0.0         1.0     3.0

# %%
bikes.season.value_counts().sort_values(ascending=True)
# Out:
# season
# 2.0    4303
# 3.0    4330
# 1.0    4387
# 0.0    4394
# Name: count, dtype: int64

# %%
#changing season number to names of the season
season_dic = {
    '0.0':'Spring',
    '1.0':'Summer',
    '2.0':'Autumn',
    '3.0':'Winter'}

# %%
bikes.weather.value_counts()
# Out:
# weather
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: count, dtype: int64

# %%
#changing weather number to the type of weather condition
weather_dic ={
    '1.0':'Clear',
    '2.0':'Scattered Clouds',
    '3.0':'Broken Clouds',
    '4.0':'Cloudy',
    '7.0':'Rain',
    '10.0':'Rain with Thunderstorms',
    '26.0':'Snowfall'
}

# %%
bikes.season=bikes.season.astype(str)
bikes.season = bikes.season.map(season_dic)

# %%
bikes.weather = bikes.weather.astype(str)
bikes.weather = bikes.weather.map(weather_dic)

# %%
bikes.head()
# Out:
#                   time  count  temp_real_C  temp_feels_like_C  humidity_per  \
# 0  2015-01-04 00:00:00    182          3.0                2.0         0.930
# 1  2015-01-04 01:00:00    138          3.0                2.5         0.930
# 2  2015-01-04 02:00:00    134          2.5                2.5         0.965
# 3  2015-01-04 03:00:00     72          2.0                2.0         1.000
# 4  2015-01-04 04:00:00     47          2.0                0.0         0.930
#
#    wind_speed_percent        weather  is_holiday  is_weekend  season
# 0                 6.0  Broken Clouds         0.0         1.0  Winter
# 1                 5.0          Clear         0.0         1.0  Winter
# 2                 0.0          Clear         0.0         1.0  Winter
# 3                 0.0          Clear         0.0         1.0  Winter
# 4                 6.5          Clear         0.0         1.0  Winter

# %%
bikes.to_excel("london_bikes_final.xlsx",sheet_name="Data")
